# %% [markdown]
# <a href="https://colab.research.google.com/github/Havynse/hys/blob/master/matplotlib_exercise(fixed).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **MATPLOTLIB EXERCISE**

# %% [markdown]
# **1. Import Matplotlib & Numpy**

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **2. Preparing data**
#
# Create x vector which has 100 elements and the element values gradually increase from 0 to 99.
#
# Randomly create y vector which has 100 elements and the element values are randomly generated in the range of \[0, 1000)

# %%
x = np.arange(0,100)
y = np.random.randint(low = 0 , high = 1000 , size =100)

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# **3. Draw a line chart**
#
# Use the above data to draw a line chart.

# %%
x = np.arange(0,100)
y = np.random.randint( low = 100 , high = 1000 , size = 100)
plt.plot(x,y)

plt.title('graph line')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')

plt.show()

# %% [markdown]
# **4. Config the axes**
#
# Use the above generated dataset, let set the name for x-axis, y-axis and the legend of your chart.
# Suggested reading: [link](https://www.tutorialspoint.com/matplotlib/matplotlib_axes_class.htm)

# %%
x = np.arange(0,100)
y = np.random.randint( low = 100 , high = 1000 , size = 100)

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
l1 = ax.plot(y,x,'ys-')

ax.legend(labels = ( 'smartphone'))
plt.title('graph line')
plt.xlabel('X ')
plt.ylabel('Y ')
# Out:
# Text(0, 0.5, 'Y ')

# %% [markdown]
# **5. Multiple line chart**
#
# Create x vector which has 100 elements and the element values gradually increase from 0 to 99.
#
# Randomly create y1 and y2 vector which have 100 elements and the element values are randomly generated in the range of \[0, 1000)
#
# Let draw the above two lines y1 and y2. The chart must has:
#
#
# 1.   names of x-axis and y-axis
# 2.   chart legend
# 3.   different colors for the lines of y1 and y2
# 4.   different markers for the lines of y1 and y2

# %%
x = np.arange(0,100)
y1 = np.random.randint( low = 0 , high = 1000 ,size = 100 )
y2 = np.random.randint( low = 500, high = 1000 , size = 100)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
l1 = ax.plot(y1,x,'bo:')
l2 = ax.plot(y2,x,'cD:')
ax.legend(labels = ('pc', 'console'), loc = 'lower center')
ax.set_title("Advertisement effect on sales")
ax.set_xlabel('medium')
ax.set_ylabel('sales')
plt.show()

# %% [markdown]
# **6. Draw a box plot**
#
# Use the above y1, y2 vectors to draw a box plot.

# %%
y1 = np.random.randint( low = 0 , high = 1000 ,size = 100 )
y2 = np.random.randint( low = 500, high = 1000 , size = 100)
data_to_box_plot = [y1,y2]

plt. boxplot(data_to_box_plot)
plt.show()

# %% [markdown]
# **7. Draw a histogram**
#
# Suggested reading: [link](https://www.tutorialspoint.com/matplotlib/matplotlib_histogram.htm). You make your own data.

# %%
smoker_man = np.array([ 134 , 31 ,90 ,200 , 50 , 60 ,55 , 150 , 184 , 259])
smoker_women = np.array([34, 100, 234, 43,55,200 , 125])
plt.hist([smoker_man,smoker_women], bins = [80,100,125,150] , rwidth=1, color=['blue','orange'],label=['men','women'])
plt.title("proportions of smoker")
plt.xlabel('smoke range')
plt.ylabel('smoke habit')
plt.legend()

# %% [markdown]
# **8. Draw a bar plot**
#
# Suggested reading: [link](https://www.tutorialspoint.com/matplotlib/matplotlib_bar_plot.htm). You make your own data.

# %%
y1 = np.random.randint( low = 0 , high = 1000 ,size = 100 )
y2 = np.random.randint( low = 500, high = 1000 , size = 100)

plt.xticks(x,company)
plt.title('US tech')
plt.ylabel("income")
plt.bar(x, y1, label="income")
plt.bar(x, y2, label="Profit")

plt.legend()

# %%
x = np.arange(len(company))
x
# Out:
# array([0, 1, 2, 3])

# %% [markdown]
# **9. Draw a scatter plot**
#
# Use the above x, y1, y2 vectors to draw a scatter plot. Suggested reading: [link](https://www.tutorialspoint.com/matplotlib/matplotlib_scatter_plot.htm)

# %%
y1 = np.random.randint( low = 0 , high = 1000 ,size = 100 )
y2 = np.random.randint( low = 500, high = 1000 , size = 100)
x = np.arange(0,100)

plt.scatter(y2, x, color="g")
plt.scatter(y2 , y1, color="r")
plt.xlabel("range")
plt.ylabel("score")
plt.title("plot")
plt.show()

# %% [markdown]
# **10. Subplot**
#
# Combine the plots of sections 4, 5, 6, 7, 8, and 9 into a multi-plot. Suggested reading: [link](https://www.tutorialspoint.com/matplotlib/matplotlib_subplots_function.htm)

# %%
x = np.arange(0,100)
y = np.random.randint( low = 100 , high = 1000 , size = 100)
fig, a = plt.subplots(3,2)
a[0][0].plot(x,y)
a[0][0].set_title('graph line')
a[0][0].set_xlabel('X Axis')
a[0][0].set_label('Y Axis')
a[0][0].legend()

y1 = np.random.randint( low = 0 , high = 1000 ,size = 100 )
y2 = np.random.randint( low = 500, high = 1000 , size = 100)

a[0][1].plot(y1,x, 'bo:')
a[0][1].plot(y2,x, 'cD:')
a[0][1].legend(labels = ('pc', 'console'), loc = 'lower center')
a[0][1].set_title("Advertisement effect on sales")
a[0][1].set_xlabel('medium')
a[0][1].set_ylabel('sales')
a[0][1].legend()

data_to_box_plot = [y1,y2]
a[1][0].boxplot(data_to_box_plot)
a[1][0].legend()

smoker_man = np.array([ 134 , 31 ,90 ,200 , 50 , 60 ,55 , 150 , 184 , 259])
smoker_women = np.array([34, 100, 234, 43,55,200 , 125])
a[1][1].hist([smoker_man,smoker_women], bins = [80,100,125,150] , rwidth=1, color=['blue','orange'],label=['men','women'])
a[1][1].set_title('proportions of smoker')
a[1][1].set_xlabel('smoke range')
a[1][1].set_ylabel('smoke habit')
a[1][1].legend()


a[2][0].set_xticks(x,company)
a[2][0].set_title('US tech')
a[2][0].set_ylabel('income')
a[2][0].bar(x , y1, label="income")
a[2][0].bar(x , y2, label="profit")
a[2][0].legend()

a[2][1].scatter(y2, x,color="g")
a[2][1].scatter(y2, y1,color="r")
a[2][1].set_xlabel('range')
a[2][1].set_ylabel('score')
a[2][1].set_title('plot')
a[2][1].legend()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:35: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
# No handles with labels found to put in legend.
